# %%
import os
import glob
import pandas as pd
import numpy as np
import wikipedia

# %%
os.chdir("C:/Users/raymo/code/pin-lpt/uncancelled_master/data/WikipediaEditHistory")

# %%
df = pd.read_csv('cleaned_wiki_edit.csv')

# %%
df1 = pd.DataFrame(df['page_title'].unique())[:1000]

# %%
df2 = pd.DataFrame(df['page_title'].unique())[1000:2000]

# %%
df3 = pd.DataFrame(df['page_title'].unique())[2000:]

# %%
df1[0][29]
# Out:
# '2016 Denmark Super Series Premier'

# %%
wikipedia.page(wikipedia.search("2015 afl season")[0]).content
# Out:
# 'The 2015 Australian Football League season was the 119th season of the elite Australian rules football competition and the 26th under the name \'Australian Football League\', having switched from \'Victorian Football League\' after 1989. There were 18 teams competing in the league, the same as the previous year. The first game was played on Thursday, 2 April, and the Grand Final was played on Saturday, 3 October, with Hawthorn defeating West Coast by 46 points to win its 13th premiership and its third in successive years.\nNat Fyfe won the Brownlow Medal, voted by the umpires to be the best and fairest player in the league for the home-and-away season. Josh Kennedy won the Coleman Medal as the highest goal scorer in the competition.\nThe season was marred by the mid-season death of Adelaide senior coach Phil Walsh.\n\n\n== Pre-season ==\n\n\n=== All Stars game ===\nThe biennial All Stars game, this year played in Western Australia, featuring an AFL team and the Indigenous All Stars 
# ...

# %%
wiki1 =[]
for i in range(len(df1)):
    wiki1.append(wikipedia.page(wikipedia.search(df1[0][i])[0], auto_suggest=False).content)

# %%
df_wiki1 = pd.DataFrame(wiki1)

# %%
df1['content'] = df_wiki1[0]

# %%
df1
# Out:
#                                                      0  \
# 0                      "Polish death camp" controversy
# 1                                 'Ubadah ibn al-Samit
# 2                         116th United States Congress
# 3                                       13 Reasons Why
# 4                        1721 Boston smallpox outbreak
# 5                                                 1900
# 6                                     1917 (2019 film)
# 7    1993 NCAA Division I Outdoor Track and Field C...
# 8                              1999 Matamoros standoff
# 9    1999 NCAA Division I Outdoor Track and Field C...
# 10                                19 Kids and Counting
# 11                                          2.0 (film)
# 12   2000 NCAA Division I Outdoor Track and Field C...
# 13                              2002 Stromboli tsunami
# 14   2007 NCAA Division I Indoor Track and Field Ch...
# 15   2008 NCAA Division I Indoor Track and Field Ch...
# ...

# %%
df1.columns = ['title', 'content']

# %%
df1.to_csv("wiki_edit_content_1.csv")

# %%
df2 = df2.reset_index()

# %%
df2.drop(columns=['index'], inplace=True)

# %%
wiki2 =[]
for i in range(len(df2)):
    wiki2.append(wikipedia.page(wikipedia.search(df2[0][i])[0], auto_suggest=False).content)

df_wiki2 = pd.DataFrame(wiki2)
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# c:\users\raymo\.venvs\lewagon\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#
# c:\users\raymo\.venvs\lewagon\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# c:\users\raymo\.venvs\lewagon\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ...

# %%
df2.columns = ['title', 'content']
df2.to_csv("wiki_edit_content_2.csv")

# %%
df3 = df3.reset_index()
df3.drop(columns=['index'], inplace=True)

wiki3 =[]
for i in range(len(df3)):
    wiki3.append(wikipedia.page(wikipedia.search(df3[0][i])[0], auto_suggest=False).content)

df_wiki3 = pd.DataFrame(wiki3)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# c:\users\raymo\.venvs\lewagon\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#
# c:\users\raymo\.venvs\lewagon\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         try:
# --> 381             self._validate_conn(conn)
#     382         except (SocketTimeout, BaseSSLError) as e:
#
# c:\users\raymo\.venvs\lewagon\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     975         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# ...

# %%
df3.columns = ['title', 'content']
df3.to_csv("wiki_edit_content_3.csv")
