# %%
# Import package
import wikipedia
# Specify the title of the Wikipedia page
wiki = wikipedia.page('1721 Boston smallpox outbreak')
# Extract the plain text content of the page
data = wiki.content
data
# Out:
# 'In 1721, Boston experienced its worst outbreak of smallpox (also known as variola). 5,759 people out of around 10,600 in Boston were infected and 844 were recorded to have died between April 1721 and February 1722. The outbreak would motivate Puritan minister Cotton Mather and Harvard physician Zabdiel Boylston to variolate hundreds of Bostonians in the Thirteen Colonies\' earliest experiment with public inoculation. Their efforts would inspire further use and research of variolation for immunizing people from smallpox, placing the Massachusetts Bay Colony at the epicenter of the Colonies\' first inoculation debate and profoundly impacting Western society\'s medical treatment of the disease. The outbreak also permanently changed social and religious public discourse about disease, as Boston\'s newspapers published various pamphlets opposing and supporting the inoculation efforts.\n\n\n== Smallpox in Boston ==\n \nOn 22 April 1721 the British passenger ship HMS Seahorse arrived at Boston from Barbados, after one stop at Tortuga, with a crew of sailors who\'d just survived smallpox. Customs\' quarantine hospital at Spectacle Island was tasked with containing individuals who had contagious diseases, with a case of smallpox contained successfully the previous fall. But one of Seahorse\'s sailors fell ill in Boston Harbor a day after arrival, and exposed other sailors to variola. Boston\'s water bailiff inspected Seahorse and discovered another two or three cases of smallpox in various stages before ordering the ship to leave the harbor. Despite the sailor being hurriedly quarantined in the lodging house where he fell ill, nine other sailors at Boston Harbor exposed to him came down with smallpox in early May. The sailors were quarantined on Spectacle Island\'s very-rudimentary hospital but staff and customs were unable to contain the virus. On 26 May Cotton Mather wrote in his diary: "The grievous calamity of the small pox has now entered the town."Boston\'s last smallpox outbreak was in 1703, and a new generation of non immune children and young adults were vulnerable. By June the town was faced with a major public health crisis and the religious public became increasingly worried that they were the subjects of divine punishment. Around 900 people fled Boston into the countryside, likely spreading the virus. The General Court, colonial Massachusetts\' legislating body, moved from Boston to Cambridge at summer\'s end, but smallpox cases began appearing in Cambridge in August. James Franklin\'s The New England Courant was founded in August amid the outbreak and the issue of smallpox and preservation from it became front page news. The Courant was ordered in early October by the town council to publish a house-by-house count on those affected so far by smallpox: 2,757 cases, 1,499 recoveries and 203 deaths were counted. The outbreak peaked in October when 411 people died in that month alone.  Judge Samuel Sewall recorded in his diary the deaths of his friends and neighbors like one Madam Checkly on 18 October. Thanksgiving sermons were also affected by the outbreak, and on 26 October most congregations held a single sermon at 11 in the morning out of fear of smallpox spreading during gatherings. The next day Judge Sewell attended the funeral of local child Edward Rawson before attending the burial of one of Sewell\'s own tenants, while a local college student and "many others" were buried that Friday night. 8% of Boston\'s population would die during the epidemic, and hundreds of other Bostonians would recover with severe scarring or disabilities.\n\n\n=== Public inoculation campaign ===\n\nCotton Mather sent letters to Boston\'s 14 other physicians in response to the outbreak imploring them to wage a medical campaign against smallpox by inoculating their own patients or volunteers. Mather had been interested in inoculation since 1715 when his slave, Onesimus, informed Mather about a procedure in Africa which made him immune to sma ...

# %%
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np

# %% [markdown]
# stop_words = set(stopwords.words('english'))
# def rev_punc(text):
#     for punctuation in string.punctuation:
#         text = text.replace(punctuation,'')
#     return text
# def cre_low(text):
#     word_tokens = word_tokenize(text)
#     text = [w.lower() for w in word_tokens]
#     return ' '.join(text)
#
# data_clean = rev_punc(data)
# data_clean = cre_low(data_clean)

# %%
stemmer = SnowballStemmer("english")
def lemmatize_stemming(text):
    return stemmer.stem(WordNetLemmatizer().lemmatize(text, pos='v'))

# Tokenize and lemmatize
def preprocess(text):
    result=[]
    for token in gensim.utils.simple_preprocess(text) :
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
            result.append(lemmatize_stemming(token))
            
    return result

data_clean = lemmatize_stemming(data)
data_clean = [preprocess(data_clean)]

# %%
data_clean
# Out:
# [['boston',
#   'experi',
#   'worst',
#   'outbreak',
#   'smallpox',
#   'know',
#   'variola',
#   'peopl',
#   'boston',
#   'infect',
#   'record',
#   'die',
#   'april',
#   'februari',
#   'outbreak',
#   'motiv',
#   'puritan',
#   'minist',
#   'cotton',
#   'mather',
#   'harvard',
#   'physician',
#   'zabdiel',
#   'boylston',
#   'variol',
#   'hundr',
#   'bostonian',
#   'thirteen',
#   'coloni',
#   'earliest',
#   'experi',
#   'public',
#   'inocul',
#   'effort',
#   'inspir',
#   'research',
#   'variol',
#   'immun',
#   'peopl',
#   'smallpox',
#   'place',
#   'massachusett',
#   'coloni',
#   'epicent',
#   'coloni',
#   'inocul',
#   'debat',
#   'profound',
#   'impact',
#   'western',
#   'societi',
#   'medic',
#   'treatment',
#   'diseas',
#   'outbreak',
#   'perman',
#   'chang',
#   'social',
#   'religi',
#   'public',
#   'discours',
#   'diseas',
#   'boston',
#   'newspap',
#   'publish',
#   'pamphlet',
#   'oppos',
#   'support',
#   'inocul',
#   'effort',
#   'smallpox',
#   'boston',
#   'april',
#   'british',
#   'passeng',
#   'ship',
#   'seahors',
#   'arriv',
#   'boston',
#   'barbado',
#   'stop',
#   'tortuga',
#   'crew',
#   'sailor',
#   'surviv',
#   'smallpox',
#   'custom',
#   'quarantin',
#   'hospit',
#   'spectacl',
#   'island',
#   'task',
#   'contain',
#   'individu',
#   'contagi',
#   'diseas',
#   'case',
#   'smallpox',
#   'contain',
#   'success',
#   'previous',
#   'fall',
#   'seahors',
#   'sailor',
#   'fell',
#   'boston',
#   'harbor',
#   'arriv',
#   'expos',
#   'sailor',
#   'variola',
#   'boston',
#   'water',
#   'bailiff',
#   'inspect',
#   'seahors',
#   'discov',
#   'case',
#   'smallpox',
#   'stag',
#   'order',
#   'ship',
#   'leav',
#   'harbor',
#   'despit',
#   'sailor',
#   'hurri',
#   'quarantin',
#   'lodg',
#   'hous',
#   'fell',
#   'sailor',
#   'boston',
#   'harbor',
#   'expos',
#   'come',
#   'smallpox',
#   'earli',
#   'sailor',
#   'quarantin',
#   'spectacl',
#   'island',
#   'rudimentari',
#   'hospit',
#   'staff',
#   'custom',
#   'unabl',
#   'contain',
#   'virus',
#   'cotton',
#   'mather',
#   'write',
#   'diari',
#   'grievous',
#   'calam',
#   'small',
#   'enter',
#   'town',
#   'boston',
#   'smallpox',
#   'outbreak',
#   'generat',
#   'immun',
#   'children',
#   'young',
#   'adult',
#   'vulner',
#   'june',
#   'town',
#   'face',
#   'major',
#   'public',
#   'health',
#   'crisi',
#   'religi',
#   'public',
#   'increas',
#   'worri',
#   'subject',
#   'divin',
#   'punish',
#   'peopl',
#   'flee',
#   'boston',
#   'countrysid',
#   'like',
#   'spread',
#   'virus',
#   'general',
#   'court',
#   'coloni',
#   'massachusett',
#   'legisl',
#   'bodi',
#   'move',
#   'boston',
#   'cambridg',
#   'summer',
#   'smallpox',
#   'case',
#   'begin',
#   'appear',
#   'cambridg',
#   'august',
#   'jam',
#   'franklin',
#   'england',
#   'courant',
#   'found',
#   'august',
#   'amid',
#   'outbreak',
#   'issu',
#   'smallpox',
#   'preserv',
#   'page',
#   'news',
#   'courant',
#   'order',
#   'earli',
#   'octob',
#   'town',
#   'council',
#   'publish',
#   'hous',
#   'hous',
#   'count',
#   'affect',
#   'smallpox',
#   'case',
#   'recoveri',
#   'death',
#   'count',
#   'outbreak',
#   'peak',
#   'octob',
#   'peopl',
#   'die',
#   'month',
#   'judg',
#   'samuel',
#   'sewal',
#   'record',
#   'diari',
#   'death',
#   'friend',
#   'neighbor',
#   'like',
#   'madam',
#   'check',
#   'octob',
#   'thanksgiv',
#   'sermon',
#   'affect',
#   'outbreak',
#   'octob',
#   'congreg',
#   'hold',
#   'singl',
#   'sermon',
#   'morn',
#   'fear',
#   'smallpox',
#   'spread',
#   'gather',
#   'judg',
#   'sewel',
#   'attend',
#   'funer',
#   'local',
#   'child',
#   'edward',
#   'rawson',
#   'attend',
#   'burial',
#   'sewel',
#   'tenant',
#   'local',
#   'colleg',
#   'student',
#   'buri',
#   'friday',
#   'night',
#   'boston',
#   'popul',
#   'epidem',
#   'hundr',
#   'bostonian',
#   'recov',
#   'sever',
#   'scar',
#   'disabl',
#   'public',
#   'inocul',
#   'campaign',
#   'cotton',
#   'mather',
#   'send',
#   'letter',
#   'boston',
#   'physician',
#   'respons',
#   'outbreak',
#   'implor',
#   'wage',
#   'medic',
#   'campaign',
#   'smallpox',
#   'inocul',
#   'patient',
#   'volunt',
#   'mather',
#   'interest',
#   'inocul',
#   'slave',
#   'onesimus',
#   'inform',
#   'mather',
#   'procedur',
#   'africa',
#   'immun',
#   'smallpox',
#   'life',
#   'mather',
#   'read',
#   'physician',
#   'emmanuel',
#   'timoni',
#   'descript',
#   'similar',
#   'procedur',
#   'wit',
#   'serv',
#   'great',
#   'britain',
#   'ambassador',
#   'turkey',
#   'procedur',
#   'timoni',
#   'call',
#   'inocul',
#   'involv',
#   'dri',
#   'smallpox',
#   'patient',
#   'rub',
#   'scrap',
#   'skin',
#   'healthi',
#   'person',
#   'give',
#   'mild',
#   'case',
#   'confer',
#   'lifetim',
#   'immun',
#   'mather',
#   'want',
#   'prove',
#   'variol',
#   'relat',
#   'safe',
#   'effect',
#   'procedur',
#   'protect',
#   'peopl',
#   'smallpox',
#   'physician',
#   'fear',
#   'possibl',
#   'smallpox',
#   'fatal',
#   'spread',
#   'social',
#   'implic',
#   'deliber',
#   'infect',
#   'zabdiel',
#   'boylston',
#   'harvard',
#   'univers',
#   'doctor',
#   'posit',
#   'respond',
#   'mather',
#   'action',
#   'begin',
#   'america',
#   'public',
#   'campaign',
#   'inocul',
#   'june',
#   'boylston',
#   'inocul',
#   'year',
#   'thoma',
#   'year',
#   'slave',
#   'slave',
#   'year',
#   'doctor',
#   'relief',
#   'surviv',
#   'relat',
#   'mild',
#   'case',
#   'smallpox',
#   'disabl',
#   'disfigur',
#   'boylston',
#   'felt',
#   'confid',
#   'procedur',
#   'safeti',
#   'period',
#   'month',
#   'outbreak',
#   'inocul',
#   'peopl',
#   'boston',
#   'fatal',
#   'novemb',
#   'inocul',
#   'individu',
#   'harvard',
#   'thirteen',
#   'harvard',
#   'student',
#   'professor',
#   'edward',
#   'wiglesworth',
#   'tutor',
#   'william',
#   'welst',
#   'surviv',
#   'univers',
#   'student',
#   'bodi',
#   'faculti',
#   'fascin',
#   'novel',
#   'procedur',
#   'cotton',
#   'mather',
#   'write',
#   'letter',
#   'detail',
#   'boylston',
#   'work',
#   'boston',
#   'experi',
#   'hundr',
#   'person',
#   'male',
#   'femal',
#   'young',
#   'strong',
#   'weak',
#   'white',
#   'black',
#   'boylston',
#   'unabl',
#   'continu',
#   'inocul',
#   'campaign',
#   'novemb',
#   'opposit',
#   'boston',
#   'selectmen',
#   'restrict',
#   'occasion',
#   'violenc',
#   'public',
#   'tutor',
#   'harvard',
#   'inspir',
#   'research',
#   'thoma',
#   'robi',
#   'continu',
#   'vaccin',
#   'patient',
#   'spectacl',
#   'island',
#   'patient',
#   'tutor',
#   'nichola',
#   'sevier',
#   'return',
#   'harvard',
#   'sixteen',
#   'day',
#   'inocul',
#   'report',
#   'success',
#   'procedur',
#   'harvard',
#   'academ',
#   'communiti',
#   'accept',
#   'inocul',
#   'success',
#   'experi',
#   'boylston',
#   'nichola',
#   'sevier',
#   'inocul',
#   'controversi',
#   'violenc',
#   'cotton',
#   'mather',
#   'believ',
#   'inocul',
#   'divin',
#   'gift',
#   'protect',
#   'peopl',
#   'smallpox',
#   'boylston',
#   'felt',
#   'duti',
#   'bind',
#   'inocul',
#   'protect',
#   'children',
#   'smallpox',
#   'contemporari',
#   'especi',
#   'regular',
#   'bostonian',
#   'knowledg',
#   'inocul',
#   'terrifi',
#   'smallpox',
#   'spread',
#   'inocul',
#   'patient',
#   'outrag',
#   'idea',
#   'deliber',
#   'infect',
#   'peopl',
#   'inocul',
#   'evok',
#   'anger',
#   'dubious',
#   'physician',
#   'william',
#   'douglass',
#   'vehement',
#   'inocul',
#   'oppon',
#   'publish',
#   'anti',
#   'inocul',
#   'pamphlet',
#   'respons',
#   'mather',
#   'experi',
#   'pamphlet',
#   'publish',
#   'england',
#   'courant',
#   'read',
#   'carri',
#   'instrument',
#   'inocul',
#   'bottl',
#   'poison',
#   'humor',
#   'infect',
#   'will',
#   'submit',
#   'infect',
#   'famili',
#   'morn',
#   'pray',
#   'even',
#   'distemp',
#   'spread',
#   'douglass',
#   'believ',
#   'accredit',
#   'medic',
#   'profession',
#   'like',
#   'conduct',
#   'danger',
#   'procedur',
#   'person',
#   'oppos',
#   'inocul',
#   'boylston',
#   'ridicul',
#   'satir',
#   'newspap',
#   'portray',
#   'quack',
#   'douglass',
#   'french',
#   'local',
#   'physician',
#   'name',
#   'dalhond',
#   'variol',
#   'present',
#   'inher',
#   'risk',
#   'death',
#   'undergo',
#   'procedur',
#   'provid',
#   'fertil',
#   'grind',
#   'voic',
#   'oppos',
#   'furious',
#   'rumor',
#   'swirl',
#   'inocul',
#   'england',
#   'courant',
#   'publish',
#   'douglass',
#   'dalhond',
#   'sensationalist',
#   'articl',
#   'inocul',
#   'articl',
#   'douglass',
#   'dark',
#   'joke',
#   'smallpox',
#   'inocul',
#   'kill',
#   'surround',
#   'nativ',
#   'communiti',
#   'inocul',
#   'boylston',
#   'notori',
#   'coloni',
#   'govern',
#   'reject',
#   'notion',
#   'inocul',
#   'deepli',
#   'skeptic',
#   'mather',
#   'experi',
#   'boston',
#   'citi',
#   'council',
#   'summon',
#   'boylston',
#   'earli',
#   'august',
#   'explain',
#   'council',
#   'condemn',
#   'inocul',
#   'order',
#   'desist',
#   'immedi',
#   'despit',
#   'opposit',
#   'boylston',
#   'garner',
#   'support',
#   'local',
#   'learn',
#   'like',
#   'cotton',
#   'father',
#   'increas',
#   'mather',
#   'inocul',
#   'minist',
#   'benjamin',
#   'coleman',
#   'thoma',
#   'princ',
#   'john',
#   'webb',
#   'william',
#   'cooper',
#   'defiant',
#   'resum',
#   'inocul',
#   'patient',
#   'later',
#   'boylston',
#   'assault',
#   'street',
#   'eventu',
#   'life',
#   'threaten',
#   'point',
#   'boylston',
#   'secret',
#   'hous',
#   'week',
#   'cotton',
#   'mather',
#   'terror',
#   'angri',
#   'public',
#   'rumor',
#   'spread',
#   'wild',
#   'inocul',
#   'angri',
#   'mob',
#   'eventu',
#   'begin',
#   'forc',
#   'variol',
#   'isol',
#   'spectacl',
#   'island',
#   'quarantin',
#   'hous',
#   'cotton',
#   'mather',
#   'nephew',
#   'reverend',
#   'walter',
#   'inocul',
#   'offer',
#   'stay',
#   'mather',
#   'home',
#   'recov',
#   'smallpox',
#   'fear',
#   'attack',
#   'hous',
#   'throw',
#   'crude',
#   'bomb',
#   'direct',
#   'room',
#   'walter',
#   'stay',
#   'devic',
#   'fail',
#   'explod',
#   'note',
#   'tie',
#   'devic',
#   'read',
#   'cotton',
#   'mather',
#   'meet',
#   'curs',
#   'tell',
#   'know',
#   'leav',
#   'damn',
#   'inocul',
#   'promin',
#   'member',
#   'boston',
#   'clergi',
#   'oppos',
#   'inocul',
#   'john',
#   'william',
#   'william',
#   'critic',
#   'variol',
#   'sin',
#   'rule',
#   'natur',
#   'physick',
#   'cotton',
#   'mather',
#   'counter',
#   'reject',
#   'inocul',
#   'violat',
#   'bibl',
#   'command',
#   'peopl',
#   'social',
#   'scientif',
#   'impact',
#   'outbreak',
#   'time',
#   'american',
#   'medicin',
#   'press',
#   'inform',
#   'alarm',
#   'general',
#   'public',
#   'health',
#   'crisi',
#   'england',
#   'courant',
#   'leadership',
#   'editor',
#   'year',
#   'benjamin',
#   'franklin',
#   'continu',
#   'publish',
#   'satir',
#   'articl',
#   'mather',
#   'inocul',
#   'month',
#   'follow',
#   'epidem',
#   'boylston',
#   'write',
#   'account',
#   'experi',
#   'inocul',
#   'histor',
#   'account',
#   'small',
#   'inocul',
#   'england',
#   'boston',
#   'clergi',
#   'support',
#   'inocul',
#   'write',
#   'oppos',
#   'william',
#   'douglass',
#   'critic',
#   'boylston',
#   'academ',
#   'educ',
#   'congruent',
#   'letter',
#   'physician',
#   'town',
#   'ought',
#   'mean',
#   'call',
#   'illiter',
#   'ignor',
#   'town',
#   'bear',
#   'cutter',
#   'davi',
#   'treat',
#   'minist',
#   'benjamin',
#   'coleman',
#   'believ',
#   'inocul',
#   'collect',
#   'inocul',
#   'stori',
#   'slave',
#   'similar',
#   'onesimus',
#   'account',
#   'publish',
#   'observ',
#   'method',
#   'receiv',
#   'small',
#   'ingraft',
#   'inocul',
#   'opposit',
#   'douglass',
#   'boston',
#   'smallpox',
#   'outbreak',
#   'uniqu',
#   'motiv',
#   'america',
#   'public',
#   'inocul',
#   'campaign',
#   'controversi',
#   'surround',
#   'februari',
#   'offici',
#   'announc',
#   'case',
#   'smallpox',
#   'appear',
#   'boston',
#   'diseas',
#   'declin',
#   'outbreak',
#   'aftermath',
#   'bostonian',
#   'dead',
#   'disfigur',
#   'smallpox',
#   'boylston',
#   'inocul',
#   'patient',
#   'death',
#   'rate',
#   'versus',
#   'peopl',
#   'die',
#   'smallpox',
#   'natur',
#   'boylston',
#   'success',
#   'experi',
#   'student',
#   'faculti',
#   'harvard',
#   'lead',
#   'earli',
#   'accept',
#   'boston',
#   'power',
#   'academ',
#   'communiti',
#   'procedur',
#   'mather',
#   'boylston',
#   'high',
#   'public',
#   'experi',
#   'inocul',
#   'ladi',
#   'mari',
#   'wortley',
#   'montagu',
#   'similar',
#   'experi',
#   'simultan',
#   'outbreak',
#   'london',
#   'variol',
#   'widespread',
#   'research',
#   'techniqu',
#   'west',
#   'decad',
#   'edward',
#   'jenner',
#   'discoveri',
#   'vaccin',
#   'cowpox',
#   'refer']]

# %%
dictionary = gensim.corpora.Dictionary(data_clean)

# %%
count = 0
for k, v in dictionary.iteritems():
    print(k, v)
    count += 1
    if count > 10:
        break
# Out:
# 0 academ
# 1 accept
# 2 account
# 3 accredit
# 4 action
# 5 adult
# 6 affect
# 7 africa
# 8 aftermath
# 9 alarm
# 10 ambassador

# %%
'''
Create the Bag-of-words model for each document i.e for each document we create a dictionary reporting how many
words and how many times those words appear. Save this to 'bow_corpus'
'''
bow_corpus = [dictionary.doc2bow(doc) for doc in data_clean]

# %%
bow_corpus
# Out:
# [[(0, 3),
#   (1, 2),
#   (2, 3),
#   (3, 1),
#   (4, 1),
#   (5, 1),
#   (6, 2),
#   (7, 1),
#   (8, 1),
#   (9, 1),
#   (10, 1),
#   (11, 2),
#   (12, 1),
#   (13, 1),
#   (14, 1),
#   (15, 2),
#   (16, 1),
#   (17, 1),
#   (18, 2),
#   (19, 2),
#   (20, 2),
#   (21, 3),
#   (22, 1),
#   (23, 1),
#   (24, 2),
#   (25, 3),
#   (26, 1),
#   (27, 1),
#   (28, 1),
#   (29, 3),
#   (30, 3),
#   (31, 3),
#   (32, 1),
#   (33, 1),
#   (34, 1),
#   (35, 2),
#   (36, 1),
#   (37, 22),
#   (38, 4),
#   (39, 1),
#   (40, 19),
#   (41, 1),
#   (42, 1),
#   (43, 1),
#   (44, 1),
#   (45, 1),
#   (46, 2),
#   (47, 2),
#   (48, 5),
#   (49, 1),
#   (50, 7),
#   (51, 1),
#   (52, 1),
#   (53, 1),
#   (54, 2),
#   (55, 1),
#   (56, 2),
#   (57, 2),
#   (58, 1),
#   (59, 1),
#   (60, 5),
#   (61, 1),
#   (62, 1),
#   (63, 3),
#   (64, 1),
#   (65, 1),
#   (66, 1),
#   (67, 1),
#   (68, 1),
#   (69, 1),
#   (70, 1),
#   (71, 3),
#   (72, 1),
#   (73, 3),
#   (74, 2),
#   (75, 1),
#   (76, 10),
#   (77, 3),
#   (78, 2),
#   (79, 1),
#   (80, 1),
#   (81, 5),
#   (82, 1),
#   (83, 1),
#   (84, 1),
#   (85, 2),
#   (86, 2),
#   (87, 1),
#   (88, 1),
#   (89, 2),
#   (90, 1),
#   (91, 2),
#   (92, 1),
#   (93, 1),
#   (94, 1),
#   (95, 1),
#   (96, 1),
#   (97, 1),
#   (98, 4),
#   (99, 1),
#   (100, 1),
#   (101, 1),
#   (102, 1),
#   (103, 1),
#   (104, 2),
#   (105, 1),
#   (106, 1),
#   (107, 2),
#   (108, 1),
#   (109, 2),
#   (110, 2),
#   (111, 3),
#   (112, 1),
#   (113, 2),
#   (114, 1),
#   (115, 1),
#   (116, 1),
#   (117, 4),
#   (118, 2),
#   (119, 1),
#   (120, 2),
#   (121, 2),
#   (122, 7),
#   (123, 1),
#   (124, 1),
#   (125, 1),
#   (126, 4),
#   (127, 1),
#   (128, 1),
#   (129, 1),
#   (130, 3),
#   (131, 1),
#   (132, 2),
#   (133, 1),
#   (134, 5),
#   (135, 1),
#   (136, 1),
#   (137, 2),
#   (138, 1),
#   (139, 1),
#   (140, 2),
#   (141, 1),
#   (142, 10),
#   (143, 1),
#   (144, 1),
#   (145, 2),
#   (146, 1),
#   (147, 2),
#   (148, 1),
#   (149, 1),
#   (150, 1),
#   (151, 1),
#   (152, 2),
#   (153, 1),
#   (154, 3),
#   (155, 2),
#   (156, 2),
#   (157, 2),
#   (158, 1),
#   (159, 1),
#   (160, 1),
#   (161, 1),
#   (162, 1),
#   (163, 1),
#   (164, 2),
#   (165, 1),
#   (166, 1),
#   (167, 1),
#   (168, 1),
#   (169, 1),
#   (170, 1),
#   (171, 1),
#   (172, 2),
#   (173, 1),
#   (174, 1),
#   (175, 1),
#   (176, 1),
#   (177, 1),
#   (178, 1),
#   (179, 1),
#   (180, 3),
#   (181, 8),
#   (182, 2),
#   (183, 1),
#   (184, 1),
#   (185, 1),
#   (186, 1),
#   (187, 1),
#   (188, 2),
#   (189, 6),
#   (190, 1),
#   (191, 3),
#   (192, 1),
#   (193, 1),
#   (194, 1),
#   (195, 1),
#   (196, 1),
#   (197, 4),
#   (198, 2),
#   (199, 1),
#   (200, 1),
#   (201, 2),
#   (202, 2),
#   (203, 5),
#   (204, 2),
#   (205, 1),
#   (206, 1),
#   (207, 47),
#   (208, 1),
#   (209, 2),
#   (210, 1),
#   (211, 1),
#   (212, 1),
#   (213, 4),
#   (214, 1),
#   (215, 1),
#   (216, 1),
#   (217, 1),
#   (218, 2),
#   (219, 1),
#   (220, 2),
#   (221, 2),
#   (222, 1),
#   (223, 2),
#   (224, 1),
#   (225, 1),
#   (226, 1),
#   (227, 1),
#   (228, 1),
#   (229, 1),
#   (230, 2),
#   (231, 1),
#   (232, 3),
#   (233, 2),
#   (234, 1),
#   (235, 4),
#   (236, 4),
#   (237, 1),
#   (238, 1),
#   (239, 1),
#   (240, 1),
#   (241, 1),
#   (242, 1),
#   (243, 2),
#   (244, 20),
#   (245, 1),
#   (246, 3),
#   (247, 1),
#   (248, 1),
#   (249, 1),
#   (250, 1),
#   (251, 2),
#   (252, 3),
#   (253, 1),
#   (254, 1),
#   (255, 3),
#   (256, 2),
#   (257, 2),
#   (258, 1),
#   (259, 1),
#   (260, 1),
#   (261, 2),
#   (262, 1),
#   (263, 1),
#   (264, 1),
#   (265, 2),
#   (266, 2),
#   (267, 1),
#   (268, 1),
#   (269, 1),
#   (270, 1),
#   (271, 1),
#   (272, 2),
#   (273, 1),
#   (274, 1),
#   (275, 4),
#   (276, 1),
#   (277, 1),
#   (278, 2),
#   (279, 1),
#   (280, 5),
#   (281, 3),
#   (282, 3),
#   (283, 1),
#   (284, 13),
#   (285, 1),
#   (286, 1),
#   (287, 3),
#   (288, 1),
#   (289, 7),
#   (290, 1),
#   (291, 10),
#   (292, 1),
#   (293, 1),
#   (294, 3),
#   (295, 7),
#   (296, 1),
#   (297, 1),
#   (298, 1),
#   (299, 1),
#   (300, 1),
#   (301, 1),
#   (302, 1),
#   (303, 1),
#   (304, 1),
#   (305, 1),
#   (306, 1),
#   (307, 1),
#   (308, 1),
#   (309, 1),
#   (310, 1),
#   (311, 10),
#   (312, 1),
#   (313, 1),
#   (314, 1),
#   (315, 1),
#   (316, 3),
#   (317, 1),
#   (318, 1),
#   (319, 11),
#   (320, 7),
#   (321, 1),
#   (322, 1),
#   (323, 1),
#   (324, 4),
#   (325, 1),
#   (326, 1),
#   (327, 3),
#   (328, 1),
#   (329, 2),
#   (330, 2),
#   (331, 1),
#   (332, 1),
#   (333, 1),
#   (334, 2),
#   (335, 2),
#   (336, 1),
#   (337, 2),
#   (338, 1),
#   (339, 3),
#   (340, 1),
#   (341, 2),
#   (342, 1),
#   (343, 1),
#   (344, 1),
#   (345, 1),
#   (346, 1),
#   (347, 1),
#   (348, 1),
#   (349, 1),
#   (350, 1),
#   (351, 1),
#   (352, 1),
#   (353, 2),
#   (354, 1),
#   (355, 1),
#   (356, 6),
#   (357, 1),
#   (358, 2),
#   (359, 1),
#   (360, 1),
#   (361, 1),
#   (362, 3),
#   (363, 1),
#   (364, 1),
#   (365, 1),
#   (366, 1),
#   (367, 2),
#   (368, 1),
#   (369, 1),
#   (370, 2),
#   (371, 1),
#   (372, 2),
#   (373, 2),
#   (374, 3),
#   (375, 1),
#   (376, 1),
#   (377, 1),
#   (378, 1),
#   (379, 1),
#   (380, 1),
#   (381, 4),
#   (382, 3),
#   (383, 27),
#   (384, 3),
#   (385, 1),
#   (386, 4),
#   (387, 6),
#   (388, 1),
#   (389, 1),
#   (390, 2),
#   (391, 1),
#   (392, 1),
#   (393, 1),
#   (394, 1),
#   (395, 4),
#   (396, 1),
#   (397, 1),
#   (398, 4),
#   (399, 1),
#   (400, 1),
#   (401, 3),
#   (402, 2),
#   (403, 3),
#   (404, 1),
#   (405, 1),
#   (406, 1),
#   (407, 1),
#   (408, 1),
#   (409, 1),
#   (410, 1),
#   (411, 1),
#   (412, 2),
#   (413, 3),
#   (414, 1),
#   (415, 1),
#   (416, 1),
#   (417, 1),
#   (418, 2),
#   (419, 1),
#   (420, 5),
#   (421, 1),
#   (422, 1),
#   (423, 1),
#   (424, 3),
#   (425, 2),
#   (426, 1),
#   (427, 1),
#   (428, 2),
#   (429, 2),
#   (430, 7),
#   (431, 2),
#   (432, 1),
#   (433, 1),
#   (434, 1),
#   (435, 2),
#   (436, 2),
#   (437, 1),
#   (438, 1),
#   (439, 1),
#   (440, 1),
#   (441, 2),
#   (442, 1),
#   (443, 1),
#   (444, 1),
#   (445, 1),
#   (446, 1),
#   (447, 1),
#   (448, 1),
#   (449, 1),
#   (450, 1),
#   (451, 1),
#   (452, 1),
#   (453, 1),
#   (454, 1),
#   (455, 6),
#   (456, 1),
#   (457, 1),
#   (458, 1),
#   (459, 1),
#   (460, 1),
#   (461, 4),
#   (462, 4),
#   (463, 2),
#   (464, 2)]]

# %%
lda_model =  gensim.models.LdaMulticore(bow_corpus, 
                                   num_topics = 8, 
                                   id2word = dictionary,                                    
                                   passes = 10,
                                   workers = 2)

# %%
for idx, topic in lda_model.print_topics(-1):
    print("Topic: {} \nWords: {}".format(idx, topic ))
    print("\n")
# Out:
# Topic: 0
# Words: 0.047*"inocul" + 0.027*"smallpox" + 0.022*"boston" + 0.020*"mather" + 0.019*"boylston" + 0.013*"outbreak" + 0.011*"public" + 0.010*"peopl" + 0.010*"cotton" + 0.010*"procedur"
#
#
# Topic: 1
# Words: 0.004*"inocul" + 0.004*"smallpox" + 0.004*"boylston" + 0.004*"boston" + 0.003*"mather" + 0.003*"outbreak" + 0.003*"public" + 0.003*"experi" + 0.003*"cotton" + 0.003*"procedur"
#
#
# Topic: 2
# Words: 0.002*"inocul" + 0.002*"smallpox" + 0.002*"boston" + 0.002*"boylston" + 0.002*"mather" + 0.002*"procedur" + 0.002*"outbreak" + 0.002*"public" + 0.002*"harvard" + 0.002*"douglass"
#
#
# Topic: 3
# Words: 0.002*"inocul" + 0.002*"boylston" + 0.002*"smallpox" + 0.002*"boston" + 0.002*"mather" + 0.002*"cotton" + 0.002*"outbreak" + 0.002*"peopl" + 0.002*"public" + 0.002*"patient"
#
#
# Topic: 4
# Words: 0.002*"inocul" + 0.002*"mather" + 0.002*"smallpox" + 0.002*"boylston" + 0.002*"boston" + 0.002*"peopl" + 0.002*"outbreak" + 0.002*"procedur" + 0.002*"experi" + 0.002*"cotton"
#
#
# Topic: 5
# Words: 0.003*"inocul" + 0.002*"boston" + 0.002*"smallpox" + 0.002*"boylston" + 0.002*"outbreak" + 0.002*"mather" + 0.002*"procedur" + 0.002*"experi" + 0.002*"public" + 0.002*"cotton"
#
#
# Topic: 6
# Words: 0.003*"inocul" + 0.002*"smallpox" + 0.002*"mather" + 0.002*"boylston" + 0.002*"boston" + 0.002*"outbreak" + 0.002*"public" + 0.002*"peopl" + 0.002*"harvard" + 0.002*"procedur"
#
#
# Topic: 7
# Words: 0.002*"inocul" + 0.002*"smallpox" + 0.002*"boston" + 0.002*"boylston" + 0.002*"mather" + 0.002*"outbreak" + 0.002*"procedur" + 0.002*"experi" + 0.002*"patient" + 0.002*"cotton"

# %% [markdown]
# from sklearn.decomposition import LatentDirichletAllocation
# from sklearn.feature_extraction.text import TfidfVectorizer
#
# vectorizer = TfidfVectorizer().fit(data_clean)
# data_vectorized = vectorizer.transform(data_clean)
# lda_model = LatentDirichletAllocation(n_components=10).fit(data_vectorized)

# %% [markdown]
# def print_topics(model, vectorizer):
#     for idx, topic in enumerate(model.components_):
#         print("Topic %d:" % (idx))
#         print([(vectorizer.get_feature_names()[i], topic[i])
#                         for i in topic.argsort()[:-10 - 1:-1]])
#
# print_topics(lda_model, vectorizer)
